# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyanshJain907/GenAi_Monday_lab/blob/main/GenAi_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q diffusers transformers accelerate safetensors

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
).to("cuda")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# text_encoder/model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# safety_checker/model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
prompt = "a cinematic dog city at night, ultra realistic, 4k"

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.5
).images[0]

image
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import os

# ---------------------------
# Dog breed list (10)
# ---------------------------
dog_breeds = [
    "golden retriever",
    "german shepherd",
    "labrador retriever",
    "beagle",
    "pug",
    "rottweiler",
    "doberman pinscher",
    "siberian husky",
    "french bulldog",
    "Shih Tzu"
    "border collie"
]

# ---------------------------
# Dataset config
# ---------------------------
output_dir = "dog_dataset"
images_per_breed = 10  # increase if needed
num_steps = 30
guidance = 7.5

os.makedirs(output_dir, exist_ok=True)

for breed in dog_breeds:
    breed_dir = os.path.join(output_dir, breed.replace(" ", "_"))
    os.makedirs(breed_dir, exist_ok=True)

    for i in range(images_per_breed):
        prompt = (
            f"a high quality photo of a {breed}, "
            f"ultra realistic, cinematic lighting, 4k, sharp focus"
        )

        image = pipe(
            prompt,
            num_inference_steps=num_steps,
            guidance_scale=guidance
        ).images[0]

        filename = f"{breed.replace(' ', '_')}_{i}.png"
        image_path = os.path.join(breed_dir, filename)
        image.save(image_path)

        print(f"Saved: {image_path}")

print("Dataset generation complete.")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/golden_retriever/golden_retriever_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/german_shepherd/german_shepherd_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/labrador_retriever/labrador_retriever_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/beagle/beagle_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/pug/pug_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/rottweiler/rottweiler_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/doberman_pinscher/doberman_pinscher_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/siberian_husky/siberian_husky_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/french_bulldog/french_bulldog_9.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_0.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_1.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_2.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_3.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_4.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_5.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_6.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_7.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_8.png
#   0%|          | 0/30 [00:00<?, ?it/s]
# Saved: dog_dataset/Shih_Tzuborder_collie/Shih_Tzuborder_collie_9.png
# Dataset generation complete.
